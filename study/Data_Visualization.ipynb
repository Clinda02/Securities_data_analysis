# %% [markdown]
# <a href="https://colab.research.google.com/github/Clinda02/financial_data_analysis/blob/main/stock/study/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **기본함수**

# %%
import matplotlib.pyplot as plt

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
prices = [100, 102, 101, 105, 103]

plt.figure(figsize=(10, 6))
plt.title("Stock Prices Over 5 Days")
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(dates, prices, marker='o', label='Stock Price', color='blue')#, linestyle='--')
plt.legend()
plt.grid()
plt.ylim(95, 110)
plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
# 다중 플롯
plt.subplot(1, 2, 1)
plt.plot(dates, prices, marker='o', color='green')
plt.title("Stock Prices - Subplot 1")
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
plt.bar(dates, prices, color='orange')
plt.title("Stock Prices - Subplot 2")
plt.xticks(rotation=45)

plt.show()
plt.savefig("stock_prices_5_days.png")

# %% [markdown]
# # **기본함수 - seaborn**

# %%
import seaborn as sns
import pandas as pd

data = sns.load_dataset('titanic')

sns.set()
sns.set_style('whitegrid')
sns.set_palette('deep')

summary = data.describe()
print(summary)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.countplot(x='class', data=data)
plt.title("Count of Passengers by Class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # **선 그래프(matplotlib)**

# %%
import matplotlib.pyplot as plt

dates = ['2024-09-01', '2024-09-02', '2024-09-03', '2024-09-04', '2024-09-05']
A_prices = [100, 110, 120, 130, 150]
B_prices = [130, 115, 125, 120, 120]

plt.figure(figsize=(12, 6))


plt.plot(dates, A_prices, marker='o', label='Stock A', color='blue', linestyle='-') #linestyle='--', linewidth=2
plt.plot(dates, B_prices, marker='o', label='Stock B', color='orange')

plt.title("Stock Price Trend Comparison")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.xticks()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **선 그래프(SNS)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

dates = ['2024-09-01', '2024-09-02', '2024-09-03', '2024-09-04', '2024-09-05']
A_prices = [100, 110, 120, 130, 150]
B_prices = [130, 115, 125, 120, 120]

plt.figure(figsize=(12, 6))
sns.lineplot(x=dates, y=A_prices, marker='o', label='Stock A', color='blue')
sns.lineplot(x=dates, y=B_prices, marker='o', label='Stock B', color='orange')

plt.title("Stock Price Trend Comparison")
plt.xlabel("Date")
plt.ylabel("Price")
plt.legend()
plt.grid()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **선 그래프(Plotly)**

# %%
import plotly.graph_objects as go

dates = ['2024-09-01', '2024-09-02', '2024-09-03', '2024-09-04', '2024-09-05']
A_prices = [100, 110, 120, 130, 150]
B_prices = [130, 115, 125, 120, 120]

fig = go.Figure()

fig.add_trace(go.Scatter(x=dates, y=A_prices, mode='lines+markers', name='Stock A', line=dict(color='blue')))
fig.add_trace(go.Scatter(x=dates, y=B_prices, mode='lines+markers', name='Stock B', line=dict(color='orange')))

fig.update_layout(
    title="Stock Price Trend Comparison",
    xaxis_title="Date",
    yaxis_title="Price",
    xaxis_tickangle=-45,
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **막대 그래프(matplotlib)**

# %%
import matplotlib.pyplot as plt
import numpy as np

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_A = [100, 102, 101, 105, 103]
stock_B = [95, 105, 102, 85, 101]
stock_C = [99, 101, 100, 107, 104]

x = np.arange(len(dates))
width = 0.25

plt.bar(x - width, stock_A, width, label='Stock A', color='blue') # hatch="/,x,-"
plt.bar(x, stock_B, width, label='Stock B', color='orange')
plt.bar(x + width, stock_C, width, label='Stock C', color='green')

plt.title("Stock Prices Comparison Over 5 Days")
plt.xlabel("Date")
plt.ylabel("Price")
plt.xticks(x, dates)
plt.legend()
plt.grid(axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **막대 그래프(SNS)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_A = [100, 102, 101, 105, 103]
stock_B = [95, 105, 102, 85, 101]
stock_C = [99, 101, 100, 107, 104]

data = pd.DataFrame({
    'Date': dates,
    'Stock A': stock_A,
    'Stock B': stock_B,
    'Stock C': stock_C
})

# Melt the DataFrame to long format for seaborn
data_melted = data.melt(id_vars='Date', var_name='Stock', value_name='Price')

plt.figure(figsize=(10, 6))
sns.barplot(x='Date', y='Price', hue='Stock', data=data_melted, palette=['blue', 'orange', 'green'])

plt.title("Stock Prices Comparison Over 5 Days")
plt.xlabel("Date")
plt.ylabel("Price")
plt.grid(axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **막대 그래프(Plotly)**

# %%
import plotly.graph_objects as go

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_A = [100, 102, 101, 105, 103]
stock_B = [95, 105, 102, 85, 101]
stock_C = [99, 101, 100, 107, 104]

# 막대의 폭을 계산합니다
width = 0.25
x = [0, 1, 2, 3, 4]  # x축의 인덱스

fig = go.Figure()

fig.add_trace(go.Bar(x=[i - width for i in x], y=stock_A, name='Stock A', marker_color='blue'))
fig.add_trace(go.Bar(x=x, y=stock_B, name='Stock B', marker_color='orange'))
fig.add_trace(go.Bar(x=[i + width for i in x], y=stock_C, name='Stock C', marker_color='green'))

fig.update_layout(
    title="Stock Prices Comparison Over 5 Days",
    xaxis_title="Date",
    yaxis_title="Price",
    barmode='group',
    xaxis=dict(tickvals=x, ticktext=dates),
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **산점도 그래프(matplotlib)**

# %%
import matplotlib.pyplot as plt

prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
volumes = [200, 220, 180, 250, 230, 270, 300, 290, 310, 320]
returns = [20, 10, -20, 30, -10, 20, 40, -10, 30, 50]

plt.figure(figsize=(10, 6))
plt.scatter(prices, volumes, color='blue', s=100, label='Price vs Volume', marker="s") # marker="s", alpha=0.5
plt.scatter(prices, returns, color='orange', s=100, label='Price vs Returns (Scaled)')

plt.title("Scatter Plot of Stock Prices, Volume, and Returns")
plt.xlabel("Stock Price")
plt.ylabel("Volume / Returns")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# # **산점도 그래프(SNS)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
volumes = [200, 220, 180, 250, 230, 270, 300, 290, 310, 320]
returns = [20, 10, -20, 30, -10, 20, 40, -10, 30, 50]

data = pd.DataFrame({
    'Stock Price': prices,
    'Volume': volumes,
    'Returns': returns
})

plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Stock Price', y='Volume', color='blue', s=100, label='Price vs Volume')
sns.scatterplot(data=data, x='Stock Price', y='Returns', color='orange', s=100, label='Price vs Returns (Scaled)')
plt.title("Scatter Plot of Stock Prices, Volume, and Returns")
plt.xlabel("Stock Price")
plt.ylabel("Volume / Returns")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # **산점도 그래프(Plotly)**

# %%
import plotly.graph_objects as go

prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
volumes = [200, 220, 180, 250, 230, 270, 300, 290, 310, 320]
returns = [20, 10, -20, 30, -10, 20, 40, -10, 30, 50]

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=prices,
    y=volumes,
    mode='markers',
    marker=dict(color='blue', size=10),
    name='Price vs Volume'
))

fig.add_trace(go.Scatter(
    x=prices,
    y=returns,
    mode='markers',
    marker=dict(color='orange', size=10),
    name='Price vs Returns (Scaled)'
))

fig.update_layout(
    title="Scatter Plot of Stock Prices, Volume, and Returns",
    xaxis_title="Stock Price",
    yaxis_title="Volume / Returns",
    legend=dict(x=0.1, y=0.9),
    template="plotly_white"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **히스토그램(matplotlib)**

# %%
import matplotlib.pyplot as plt
import numpy as np

stock_prices = np.random.normal(loc=100, scale=10, size=1000)

plt.figure(figsize=(10, 6))
plt.hist(stock_prices, bins=10, color='blue', alpha=0.7, edgecolor='white')
plt.title('Stock Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # **히스토그램(SNS)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

stock_prices = np.random.normal(loc=100, scale=10, size=1000)

plt.figure(figsize=(10, 6))
sns.histplot(stock_prices, bins=30, color='blue', alpha=0.7, edgecolor='black')

plt.title('Stock Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # **히스토그램(Plotly)**

# %%
import plotly.express as px
import numpy as np

stock_prices = np.random.normal(loc=100, scale=10, size=1000)

fig = px.histogram(stock_prices, nbins=30,
                   labels={'value': 'Price'},
                   title='Stock Price Distribution',
                   color_discrete_sequence=['blue'])

fig.update_traces(marker=dict(line=dict(color='black', width=1)))
fig.update_layout(xaxis_title='Price', yaxis_title='Frequency',
                  template='plotly_white')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **박스플롯(matplotlib)**

# %%
import matplotlib.pyplot as plt

stock_a_prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
stock_b_prices = [95, 97, 96, 99, 98, 100, 101, 100, 102, 105]
stock_c_prices = [110, 112, 111, 115, 114, 116, 118, 119, 120, 121]

data = [stock_a_prices, stock_b_prices, stock_c_prices]

plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=['Stock A', 'Stock B', 'Stock C'])

plt.title("Box Plot of Stock Prices")
plt.ylabel("Price")
plt.grid()

plt.show()

# %% [markdown]
# # **박스플롯(SNS)**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

stock_a_prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
stock_b_prices = [95, 97, 96, 99, 98, 100, 101, 100, 102, 105]
stock_c_prices = [110, 112, 111, 115, 114, 116, 118, 119, 120, 121]

data = [stock_a_prices, stock_b_prices, stock_c_prices]
labels = ['Stock A', 'Stock B', 'Stock C']

plt.figure(figsize=(10, 6))
sns.boxplot(data=data)

plt.title("Box Plot of Stock Prices")
plt.ylabel("Price")
plt.xticks(ticks=range(len(labels)), labels=labels)
plt.grid()

plt.show()

# %% [markdown]
# # **박스플롯(Plotly)**

# %%
import plotly.express as px
import pandas as pd

stock_a_prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
stock_b_prices = [95, 97, 96, 99, 98, 100, 101, 100, 102, 105]
stock_c_prices = [110, 112, 111, 115, 114, 116, 118, 119, 120, 121]

data = {
    'Stock A': stock_a_prices,
    'Stock B': stock_b_prices,
    'Stock C': stock_c_prices
}

df = pd.DataFrame(data)

fig = px.box(df, title="Box Plot of Stock Prices",
              labels={'value': 'Price'},
              points="all")

fig.update_layout(yaxis_title='Price',
                  template='plotly_white')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **박스플롯(Plotly) -  add_trace 사용 **

# %%
import plotly.graph_objects as go

stock_a_prices = [100, 102, 101, 105, 103, 107, 110, 108, 111, 115]
stock_b_prices = [95, 97, 96, 99, 98, 100, 101, 100, 102, 105]
stock_c_prices = [110, 112, 111, 115, 114, 116, 118, 119, 120, 121]

fig = go.Figure()

fig.add_trace(go.Box(y=stock_a_prices, name='Stock A', boxpoints=False))
fig.add_trace(go.Box(y=stock_b_prices, name='Stock B', boxpoints=False))
fig.add_trace(go.Box(y=stock_c_prices, name='Stock C', boxpoints=False))

fig.update_layout(title="Box Plot of Stock Prices",
                  yaxis_title="Price",
                  template="plotly_white")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **파이차트(matplotlib)**

# %%
import matplotlib.pyplot as plt

labels = ['Stock A', 'Stock B', 'Stock C', 'Stock D']
sizes = [40, 30, 20, 10]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
explode = (0.1, 0, 0, 0)

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)

plt.title("Stock Portfolio Distribution")
plt.show()

# %% [markdown]
# # **파이차트(Plotly)**

# %%
import plotly.graph_objects as go

labels = ['Stock A', 'Stock B', 'Stock C', 'Stock D']
sizes = [40, 30, 20, 10]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
explode = [0.1, 0, 0, 0]

# 단일 차트 그리기
fig = go.Figure(data=[go.Pie(labels=labels, values=sizes,
                               textinfo='label+percent',
                               pull=explode,
                               marker=dict(colors=colors))])

# fig = go.Figure()

# fig.add_trace(go.Pie(labels=labels, values=sizes,
#           textinfo='label+percent',
#           pull=explode,
#           marker=dict(colors=colors)))


fig.update_layout(title="Stock Portfolio Distribution")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **다중플롯(matplotlib) - subplot**

# %%
import matplotlib.pyplot as plt

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_a = [100, 102, 101, 105, 103]
stock_b = [98, 99, 97, 100, 98]

plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
plt.plot(dates, stock_a, color='blue', marker='o')
plt.title("Stock A Prices")
plt.xlabel("Date")
plt.ylabel("Price")

plt.subplot(1, 2, 2)
plt.plot(dates, stock_b, color='red', marker='s')
plt.title("Stock B Prices")
plt.xlabel("Date")
plt.ylabel("Price")

plt.tight_layout()
plt.show()

# %% [markdown]
# # **다중플롯(matplotlib) - subplots**

# %%
import matplotlib.pyplot as plt

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_a = [100, 102, 101, 105, 103]
stock_b = [98, 99, 97, 100, 98]

fig, axs = plt.subplots(1, 2, figsize=(10, 6))

axs[0].plot(dates, stock_a, color='blue', marker='o')
axs[0].set_title("Stock A Prices")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Price")

axs[1].plot(dates, stock_b, color='red', marker='s')
axs[1].set_title("Stock B Prices")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("Price")

plt.tight_layout()
plt.show()

# %% [markdown]
# # **다중플롯(SNS)**

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_a = [100, 102, 101, 105, 103]
stock_b = [98, 99, 97, 100, 98]

data = pd.DataFrame({
    'Date': dates * 2,
    'Price': stock_a + stock_b,
    'Stock': ['Stock A'] * len(stock_a) + ['Stock B'] * len(stock_b)
})

g = sns.FacetGrid(data, col='Stock', height=5, aspect=1)
g.map(sns.lineplot, 'Date', 'Price', marker='o')

g.set_titles(col_template="{col_name} Prices")
g.set_axis_labels("Date", "Price")

g.axes[0, 0].set_ylim(95, 110)
g.axes[0, 1].set_ylim(95, 105)

g.tight_layout()  # 여백 자동 조절
plt.show()

# %% [markdown]
# # **다중플롯(Plotly)**

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

dates = ['2024-10-01', '2024-10-02', '2024-10-03', '2024-10-04', '2024-10-05']
stock_a = [100, 102, 101, 105, 103]
stock_b = [98, 99, 97, 100, 98]


fig = make_subplots(rows=1, cols=2, subplot_titles=("Stock A Prices", "Stock B Prices"))

fig.add_trace(go.Scatter(x=dates, y=stock_a, mode='lines+markers', name='Stock A Prices',
                         marker=dict(color='blue')), row=1, col=1)

fig.add_trace(go.Scatter(x=dates, y=stock_b, mode='lines+markers', name='Stock B Prices',
                         marker=dict(color='red')), row=1, col=2)

fig.update_layout(title="Stock Prices",
                  xaxis_title="Date",
                  yaxis_title="Price",
                  height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # 실습 주가 데이터 비교 분석 (삼성전자 vs 카카오)

# %% [markdown]
# # yfinance 라이브러리 설치

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# 삼성전자와 카카오 주가 데이터
samsung = yf.Ticker('005930.KS')  # 삼성전자 종목 코드
kakao = yf.Ticker('035720.KS')    # 카카오 종목 코드

# 최근 1년간 두 종목 데이터
samsung_data = samsung.history(period='1y')
kakao_data = kakao.history(period='1y')

# %% [markdown]
# **matplotlib 사용하여 라인그래프 비교**

# %%
plt.figure(figsize=(12, 6))
plt.plot(samsung_data['Close'], label='Samsung Electronics', color='blue')
plt.plot(kakao_data['Close'], label='Kakao', color='orange')

plt.title('Comparison of Stock Prices: Samsung Electronics vs Kakao (Last 1 Years)')
plt.xlabel('Date')
plt.ylabel('Closing Price (KRW)')
plt.legend()
plt.grid()
plt.show()
